# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.0f}'.format
plt.ion
# Out:
# <function matplotlib.pyplot.ion()>

# %%
data=pd.read_csv("used_car_dataset.csv") 
data
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# ...

# %%
data.AskPrice = data.AskPrice.str.replace("₹", '')
data.AskPrice = data.AskPrice.str.replace(",", '')
data.AskPrice = data.AskPrice.astype('int')
data.drop(data[data["Age"]==25].index,inplace=True)

# %%
brand_counts = data['Brand'].value_counts()
plt.ion

plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar', color='skyblue')
plt.title('Brand Popularity in Used Car Listings')
plt.xlabel('Brand')
plt.ylabel('Number of Cars Listed')
plt.xticks(rotation=90)
plt.show()

# %%
plot_data = data.groupby(['Age', 'Owner'])['AskPrice'].mean().unstack()
plt.figure(figsize=(12, 8))
plot_data.plot(kind='bar', stacked=False)
plt.xlabel('Age of Cars')
plt.ylabel('Average Ask Price (INR)')
plt.title('Average Ask Price for Different Owners and Age of Cars')
plt.legend(title='Owner', loc='upper right')
plt.show()

# %%
fig, ax = plt.subplots()
avg_price_by_age = data.groupby('Age')['AskPrice'].mean().reset_index()
plt.figure(figsize=(20, 16))
ax.plot(avg_price_by_age.Age,avg_price_by_age.AskPrice,color='skyblue', marker='o', linestyle='-')
ax.ticklabel_format(useOffset=False, style='plain')
ax.set_title('Average Car Depreciation by Age')
ax.set_xlabel('Car age')
ax.set_ylabel('Avg car price')
ax.grid(True)
plt.show()

# %%
fuel_type_counts = data['FuelType'].value_counts()

plt.figure(figsize=(10, 6))
fuel_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'lightcoral', 'gold'])
plt.title('Percentage of Cars by Fuel Type')
plt.ylabel('') 
plt.show()

# %%
model_counts = pd.DataFrame(data['model'].value_counts())
model_counts=model_counts.iloc[:20,:]
# Plot the bar chart
plt.figure(figsize=(12, 8))
model_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Sales for Individual Car Models')
plt.xlabel('Car Model')
plt.ylabel('Number of Sales')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Based on the visualizations and graphs from the dataset, several key inferences can be drawn about the used car market:
#
# 1. Brand Popularity: Maruti Suzuki, Hyundai, and Honda are among the most popular brands, indicating their high trust and preference among consumers due to their reliability, affordability, and extensive service networks.
#
# 2. Price Range: The asking prices for used cars vary widely, with many cars priced between ₹2,00,000 and ₹6,00,000. This diversity caters to different budget segments, making the market accessible to a wide range of buyers.
#
# 3. Depreciation: Cars depreciate in value over time, with the steepest depreciation occurring in the first few years. The rate of depreciation slows down after the initial years.
#
# 4. Popular Models: Certain car models, such as Maruti Suzuki Swift, Hyundai i20, and Honda City, have significantly higher sales, indicating strong demand and popularity in the used car market.
